# %%
import pandas as pd

# %%
df=pd.read_csv("https://drive.google.com/uc?id=1aZNLCVO0VoHmvPNvSC2teeFmZfiViE6u&export=download")

# %%
df
# Out:
#      Index                                    Name  \
# 0        1                 Thermostat Drone Heater
# 1        2   Ultra Speaker Iron Grill Advanced One
# 2        3                 Watch Headphones Kettle
# 3        4   Portable Toaster Clock Monitor Silent
# 4        5                        Pro Toaster Oven
# ..     ...                                     ...
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ...

# %%
df.head()
# Out:
#    Index                                   Name  \
# 0      1                Thermostat Drone Heater
# 1      2  Ultra Speaker Iron Grill Advanced One
# 2      3                Watch Headphones Kettle
# 3      4  Portable Toaster Clock Monitor Silent
# 4      5                       Pro Toaster Oven
#
#                                        Description  \
# 0           Consumer approach woman us those star.
# 1  Point suggest easy money operation could white.
# 2                         Reach husband education.
# 3            Always choose school poor table main.
# 4          Worry put discuss easy back too career.
#
#                           Brand                Category  Price Currency  \
# 0                   Bradford-Yu      Kitchen Appliances     74      USD
# 1                 Douglas Group       Fitness Equipment    510      USD
# 2                 Landry-Austin  Beauty & Personal Care    254      USD
# ...

# %%
df.tail()
# Out:
#      Index                                    Name  \
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                      Description           Brand  \
# 995        Piece the fight near never once bank.   Huffman Group
# 996             Apply drive outside reach apply.  Woodward Group
# 997          Line cup course student each about.  Ramos-Cardenas
# 998  History feel worry painting only power bad.   Hooper-Bender
# 999                       Pay image either rest.      Campos Inc
#
#                    Category  Price Currency  Stock            EAN  \
# 995            Toys & Games    903      USD    737  8227581307423
# 996            Toys & Games      8      USD    330   522633507294
# ...

# %%
df.describe()
# Out:
#              Index        Price        Stock           EAN  Internal ID
# count  1000.000000  1000.000000  1000.000000  1.000000e+03  1000.000000
# mean    500.500000   506.549000   501.782000  5.130255e+12    47.690000
# std     288.819436   283.773556   292.151318  2.907413e+12    28.984202
# min       1.000000     1.000000     2.000000  4.842647e+08     1.000000
# 25%     250.750000   284.750000   243.000000  2.699217e+12    22.000000
# 50%     500.500000   497.500000   504.000000  5.118167e+12    46.000000
# 75%     750.250000   757.250000   750.250000  7.653439e+12    74.000000
# max    1000.000000   999.000000   999.000000  9.994627e+12    99.000000

# %%
df.isnull()
# Out:
#      Index   Name  Description  Brand  Category  Price  Currency  Stock  \
# 0    False  False        False  False     False  False     False  False
# 1    False  False        False  False     False  False     False  False
# 2    False  False        False  False     False  False     False  False
# 3    False  False        False  False     False  False     False  False
# 4    False  False        False  False     False  False     False  False
# ..     ...    ...          ...    ...       ...    ...       ...    ...
# 995  False  False        False  False     False  False     False  False
# 996  False  False        False  False     False  False     False  False
# 997  False  False        False  False     False  False     False  False
# 998  False  False        False  False     False  False     False  False
# 999  False  False        False  False     False  False     False  False
#
#        EAN  Color   Size  Availability  Internal ID
# ...

# %%
df.isnull().sum()
# Out:
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.size
# Out:
# 13000

# %%
df.dtypes
# Out:
# Index            int64
# Name            object
# Description     object
# Brand           object
# Category        object
# Price            int64
# Currency        object
# Stock            int64
# EAN              int64
# Color           object
# Size            object
# Availability    object
# Internal ID      int64
# dtype: object

# %%
df['Size'].unique()
# Out:
# array(['Medium', 'Small', 'XXL', 'XL', 'Extra Large', '5x7 in', 'S',
#        '12x18 in', 'M', 'L', 'Large', '50x70 cm', '10x10 cm', '8x10 in',
#        '100x200 mm', 'XS', '15x20 cm', '30x40 cm'], dtype=object)

# %%
df['Size']=df['Size'].astype('category')

# %%
df.dtypes
# Out:
# Index              int64
# Name              object
# Description       object
# Brand             object
# Category          object
# Price              int64
# Currency          object
# Stock              int64
# EAN                int64
# Color             object
# Size            category
# Availability      object
# Internal ID        int64
# dtype: object

# %%
df
# Out:
#      Index                                    Name  \
# 0        1                 Thermostat Drone Heater
# 1        2   Ultra Speaker Iron Grill Advanced One
# 2        3                 Watch Headphones Kettle
# 3        4   Portable Toaster Clock Monitor Silent
# 4        5                        Pro Toaster Oven
# ..     ...                                     ...
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ...

# %%
df['Availability'].unique()
# Out:
# array(['backorder', 'pre_order', 'in_stock', 'out_of_stock',
#        'limited_stock', 'discontinued'], dtype=object)

# %%
df['new_Availability']=df['Availability'].map({'backorder':0,'pre_order':1,'in_stock':2,'out_of_stock':3,'limited_stock':4,'discounted':5})

# %%
df
# Out:
#      Index                                    Name  \
# 0        1                 Thermostat Drone Heater
# 1        2   Ultra Speaker Iron Grill Advanced One
# 2        3                 Watch Headphones Kettle
# 3        4   Portable Toaster Clock Monitor Silent
# 4        5                        Pro Toaster Oven
# ..     ...                                     ...
# 995    996  Silent Router Phone Portable Automatic
# 996    997              Digital Treadmill Clean Go
# 997    998                  Wireless Vacuum Shaver
# 998    999  Portable Cooker Brush 360 Digital Mini
# 999   1000          Smart Watch Edge Digital Sense
#
#                                          Description  \
# 0             Consumer approach woman us those star.
# 1    Point suggest easy money operation could white.
# 2                           Reach husband education.
# 3              Always choose school poor table main.
# 4            Worry put discuss easy back too career.
# ...

# %%
df.dtypes
# Out:
# Index                  int64
# Name                  object
# Description           object
# Brand                 object
# Category              object
# Price                  int64
# Currency              object
# Stock                  int64
# EAN                    int64
# Color                 object
# Size                category
# Availability          object
# Internal ID            int64
# new_Availability     float64
# dtype: object
