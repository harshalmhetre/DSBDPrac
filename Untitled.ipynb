# %% [markdown]
# Assignment No

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x =['python','c','c++','Java']
y=[85,60,50 ,70]
c=['y','b','r','g']
plt.bar(x,y,width=0.4,color =c,edgecolor= 'black',linewidth=.5, label='harshal')
plt.legend()
plt.title('Language Popularity')
plt.xlabel('language',fontsize=15)
plt.ylabel('no.')
plt.show()

# %%
x =[1,3,5,2,4]
y=[5,3,4,1,5]

plt.scatter(x,y,color ='red',s= 200 ,marker='*',edgecolors='g')
plt.show()

# %%
x =['python','c','c++','Java']
y=[85,60,50 ,70]
c=['y','b','r','g']
plt.bar(x,y ,color =c ,)
plt.show()

# %%
import random 
import numpy as np

x = np.random.randint(10,60,(50))
print(x)
# Out:
# [34 48 17 46 25 52 39 18 47 28 40 36 13 49 57 56 17 41 53 40 30 56 40 10
#  20 31 59 26 45 11 59 13 32 58 12 26 14 24 46 41 29 43 48 47 23 20 39 53
#  55 44]

# %%
plt.hist(x,bins =20)
plt.show()
